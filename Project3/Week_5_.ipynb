# %%
import pandas as pd
import sqlite3 as sql

# %%
conn = sql.connect('/content/sql-murder-mystery.db')
print(conn)

# %%
sql1 = 'SELECT * FROM crime_scene_report'

# %%
report = pd.read_sql_query(sql1, conn)

# %%
report.head()
# Out:
#        date     type                                        description  \
# 0  20180115  robbery  A Man Dressed as Spider-Man Is on a Robbery Spree
# 1  20180115   murder                  Life? Dont talk to me about life.
# 2  20180115   murder  Mama, I killed a man, put a gun against his he...
# 3  20180215   murder                         REDACTED REDACTED REDACTED
# 4  20180215   murder  Someone killed the guard! He took an arrow to ...
#
#        city
# 0       NYC
# 1    Albany
# 2      Reno
# 3  SQL City
# 4  SQL City

# %%
sql2 = 'SELECT * FROM drivers_license'

# %%
 drivers_license = pd.read_sql_query(sql2, conn)

# %%
drivers_license.head()
# Out:
#        id  age  height eye_color hair_color  gender plate_number  car_make  \
# 0  100280   72      57     brown        red    male       P24L4U     Acura
# 1  100460   63      72     brown      brown  female       XF02T6  Cadillac
# 2  101029   62      74     green      green  female       VKY5KR     Scion
# 3  101198   43      54     amber      brown  female       Y5NZ08    Nissan
# 4  101255   18      79      blue       grey  female       5162Z1     Lexus
#
#   car_model
# 0       MDX
# 1       SRX
# 2        xB
# 3     Rogue
# 4        GS

# %%
sql3 = 'SELECT * FROM facebook_event_checkin'
fb_event_checkin = pd.read_sql_query(sql3, conn)
fb_event_checkin.head()
# Out:
#    person_id  event_id                                         event_name  \
# 0      28508      5880    Nudists are people who wear one-button suits.\n
# 1      63713      3865  but that's because it's the best book on anyth...
# 2      63713      3999           If Murphy's Law can go wrong, it will.\n
# 3      63713      6436  Old programmers never die.  They just branch t...
# 4      82998      4470               Help a swallow land at Capistrano.\n
#
#        date
# 0  20170913
# 1  20171009
# 2  20170502
# 3  20170926
# 4  20171022

# %%
sql4 = 'SELECT * FROM get_fit_now_check_in'
check_in = pd.read_sql_query(sql4, conn)
check_in.head()
# Out:
#   membership_id  check_in_date  check_in_time  check_out_time
# 0         NL318       20180212            329             365
# 1         NL318       20170811            469             920
# 2         NL318       20180429            506             554
# 3         NL318       20180128            124             759
# 4         NL318       20171027            418            1019

# %%
sql5 = 'SELECT * FROM get_fit_now_member'
get_member = pd.read_sql_query(sql5, conn)
get_member.head()
# Out:
#       id  person_id                name  membership_start_date  \
# 0  NL318      65076     Everette Koepke               20170926
# 1  AOE21      39426        Noe Locascio               20171005
# 2  2PN28      63823  Jeromy Heitschmidt               20180215
# 3  0YJ24      80651      Waneta Wellard               20171206
# 4  3A08L      32858        Mei Bianchin               20170401
#
#   membership_status
# 0              gold
# 1           regular
# 2            silver
# 3              gold
# 4            silver

# %%
sql6 = 'SELECT * FROM income '
income = pd.read_sql_query(sql6, conn)
income.head()
# Out:
#          ssn  annual_income
# 0  100009868          52200
# 1  100169584          64500
# 2  100300433          74400
# 3  100355733          35900
# 4  100366269          73000

# %%
sql7 = 'SELECT * FROM interview'
interview = pd.read_sql_query(sql7, conn)
interview.head()
# Out:
#    person_id                                         transcript
# 0      28508                ‘I deny it!’ said the March Hare.\n
# 1      63713                                                 \n
# 2      86208      way, and the whole party swam to the shore.\n
# 3      35267  lessons in here? Why, there’s hardly room for ...
# 4      33856                                                 \n

# %%
sql8 = 'SELECT * FROM person'
person = pd.read_sql_query(sql8, conn)
person.head()
# Out:
#       id                 name  license_id  address_number address_street_name  \
# 0  10000   Christoper Peteuil      993845             624        Bankhall Ave
# 1  10007  Kourtney Calderwood      861794            2791       Gustavus Blvd
# 2  10010            Muoi Cary      385336             741     Northwestern Dr
# 3  10016          Era Moselle      431897            1987       Wood Glade St
# 4  10025         Trena Hornby      550890             276       Daws Hill Way
#
#          ssn
# 0  747714076
# 1  477972044
# 2  828638512
# 3  614621061
# 4  223877684

# %% [markdown]
# Retrieving the crime scene report for the murder that occurred on Jan.15, 2018, in SQL City.

# %%
query1 = '''
SELECT * FROM crime_scene_report
WHERE city = 'SQL City'
AND type = 'murder'
AND date = '20180115';
'''
pd.read_sql_query(query1,conn)
# Out:
#        date    type                                        description  \
# 0  20180115  murder  Security footage shows that there were 2 witne...
#
#        city
# 0  SQL City

# %% [markdown]
# Checking the personal details of witnesses involved in the case

# %%
query2 = '''
 SELECT * FROM person where address_street_name=='Northwestern Dr'
 '''
a=pd.read_sql_query(query2,conn)
print("Address Number: ", max(a["address_number"]))
# Out:
# Address Number:  4919

# %%
que2= '''
SELECT * FROM person where address_number=='4919'
'''
pd.read_sql_query(que2, conn)
# Out:
#       id            name  license_id  address_number address_street_name  \
# 0  14887  Morty Schapiro      118009            4919     Northwestern Dr
#
#          ssn
# 0  111564949

# %%
q2 = '''
SELECT * FROM person where address_street_name = 'Franklin Ave'
AND name LIKE 'Annabel%'
'''
pd.read_sql_query(q2, conn)
# Out:
#       id            name  license_id  address_number address_street_name  \
# 0  16371  Annabel Miller      490173             103        Franklin Ave
#
#          ssn
# 0  318771143

# %% [markdown]
# Accessing the recorded interviews of witnesses conducted after the murder and gathering insights into their statements and potential clues.

# %%
query3 = '''
SELECT * FROM interview
WHERE person_id IN ('14887','16371');
'''
pd.read_sql_query(query3,conn)
# Out:
#    person_id                                         transcript
# 0      14887  I heard a gunshot and then saw a man run out. ...
# 1      16371  I saw the murder happen, and I recognized the ...

# %% [markdown]
# The murderer is a **Male** with a gold gym membership.

# %% [markdown]
# Investigating the gym database using details obtained from the crime scene report and witness interviews

# %%
query4 = '''
SELECT * FROM get_fit_now_member
WHERE id LIKE '48Z%'
AND membership_status = 'gold';
'''
pd.read_sql_query(query4,conn)
# Out:
#       id  person_id           name  membership_start_date membership_status
# 0  48Z7A      28819   Joe Germuska               20160305              gold
# 1  48Z55      67318  Jeremy Bowers               20160101              gold

# %% [markdown]
# Both these (suspects) share the same **gym-ID "48Z"** and have **gold membership**

# %% [markdown]
# Examining the car details associated with the crime scene.

# %%
query5 = '''
SELECT * FROM drivers_license
WHERE plate_number LIKE '%H42W%'
AND gender = 'male'
'''
pd.read_sql_query(query5,conn)
# Out:
#        id  age  height eye_color hair_color gender plate_number   car_make  \
# 0  423327   30      70     brown      brown   male       0H42W2  Chevrolet
# 1  664760   21      71     black      black   male       4H42WR     Nissan
#
#   car_model
# 0  Spark LS
# 1    Altima

# %% [markdown]
# Identifing and collecting personal details mentioned in the previous query

# %%
query6 = '''
SELECT * FROM person
WHERE license_id IN ('423327', '664760');
'''
pd.read_sql_query(query6,conn)
# Out:
#       id            name  license_id  address_number    address_street_name  \
# 0  51739  Tushar Chandra      664760             312                 Phi St
# 1  67318   Jeremy Bowers      423327             530  Washington Pl, Apt 3A
#
#          ssn
# 0  137882671
# 1  871539279

# %% [markdown]
# Determining who is identified in the previous query as a member of the gym and utilizing the gym database to confirm their membership status.

# %%
query7 = '''
SELECT * FROM get_fit_now_member
WHERE person_id IN ('51739', '67318', '78193');
'''
pd.read_sql_query(query7,conn)
# Out:
#       id  person_id           name  membership_start_date membership_status
# 0  48Z55      67318  Jeremy Bowers               20160101              gold

# %% [markdown]
# # Murder is ***JEREMY BOWERS***

# %% [markdown]
# Interviewing the murderer to get the clues of true mastermind who is behind the murder.

# %%
query8 = '''
SELECT * FROM interview
WHERE person_id = '67318';
'''
pd.read_sql_query(query8,conn)
# Out:
#    person_id                                         transcript
# 0      67318  I was hired by a woman with a lot of money. I ...

# %% [markdown]
# Case is almost to be end

# %%
query10 = '''
SELECT person.*, drivers_license.hair_color, drivers_license.gender, drivers_license.car_make, drivers_license.car_model, drivers_license.height
FROM person
INNER JOIN drivers_license ON drivers_license.id = person.license_id
INNER JOIN facebook_event_checkin ON facebook_event_checkin.person_id = person.id
WHERE drivers_license.hair_color = 'red'
  AND drivers_license.height BETWEEN 65 AND 67
  AND drivers_license.gender = 'female'
  AND drivers_license.car_make = 'Tesla'
  AND drivers_license.car_model = 'Model S';

'''
pd.read_sql_query(query10,conn)
# Out:
#       id              name  license_id  address_number address_street_name  \
# 0  99716  Miranda Priestly      202298            1883          Golden Ave
# 1  99716  Miranda Priestly      202298            1883          Golden Ave
# 2  99716  Miranda Priestly      202298            1883          Golden Ave
#
#          ssn hair_color  gender car_make car_model  height
# 0  987756388        red  female    Tesla   Model S      66
# 1  987756388        red  female    Tesla   Model S      66
# 2  987756388        red  female    Tesla   Model S      66

# %% [markdown]
# ## Real master-mind behind this crime is ***MIRANDA PRIESTLY***
# **The case is solved.**
